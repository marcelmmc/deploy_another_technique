# %% [markdown]
# # Libraries

# %%
# !pip install spotipy --upgrade
# Out:
# Requirement already satisfied: spotipy in /Users/markmouawad/miniconda3/envs/artistScraping/lib/python3.10/site-packages (2.22.1)
# Requirement already satisfied: six>=1.15.0 in /Users/markmouawad/miniconda3/envs/artistScraping/lib/python3.10/site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/markmouawad/miniconda3/envs/artistScraping/lib/python3.10/site-packages (from spotipy) (1.26.14)
# Requirement already satisfied: requests>=2.25.0 in /Users/markmouawad/miniconda3/envs/artistScraping/lib/python3.10/site-packages (from spotipy) (2.28.2)
# Requirement already satisfied: redis>=3.5.3 in /Users/markmouawad/miniconda3/envs/artistScraping/lib/python3.10/site-packages (from spotipy) (4.5.1)
# Requirement already satisfied: async-timeout>=4.0.2 in /Users/markmouawad/miniconda3/envs/artistScraping/lib/python3.10/site-packages (from redis>=3.5.3->spotipy) (4.0.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/markmouawad/miniconda3/envs/artistScraping/lib/python3.10/site-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/markmouawad/miniconda3/envs/artistScraping/lib/python3.10/site-packages (from requests>=2.25.0->spotipy) (3.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/markmouawad/miniconda3/envs/artistScraping/lib/python3.10/site-packages (from requests>=2.25.0->spotipy) (2022.12.7)

# %%
# Download extra libraries
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in d:\python3.10\lib\site-packages (1.8.2.2)
# Requirement already satisfied: numpy>=1.6.1 in d:\python3.10\lib\site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pillow in d:\python3.10\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in d:\python3.10\lib\site-packages (from wordcloud) (3.6.3)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\python3.10\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in d:\python3.10\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: cycler>=0.10 in d:\python3.10\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\python3.10\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in d:\python3.10\lib\site-packages (from matplotlib->wordcloud) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in d:\python3.10\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in d:\python3.10\lib\site-packages (from matplotlib->wordcloud) (4.38.0)
# Requirement already satisfied: six>=1.5 in d:\python3.10\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# import necessary modules
from IPython.display import Image
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt	
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import plotly.express as px
from IPython.display import display
from PIL import Image
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import plotly.io as pio
import requests

import plotly.express as px
import calendar

import plotly.offline as pyo
import plotly.graph_objs as go
import plotly.express as px
import calendar

pio.renderers.default = "notebook_connected"

# %% [markdown]
# # Graph Functions

# %%
def word_cloud(col):
	"""
	Takes in dataframe and plots a wordclous using matplotlib
	"""
	plt.subplots(figsize = (12,10))
	wordcloud = WordCloud(
							background_color = 'white',
							width = 1000,
							height = 800).generate(" ".join(col))
	plt.imshow(wordcloud)
	plt.axis('off')
	plt.show()

# %%
def create_bar_chart(serie,y,x, name):
    dist_val = serie.value_counts()
    dist_val.plot(kind='bar', xlabel=x, ylabel=y,title=name)

# %%
def create_pie_chart(panda_frame, label, count, title):
    # Create a pie chart
    
    panda_frame.plot(kind='pie', y=count, labels=panda_frame[label], autopct='%1.1f%%',figsize=(12, 12))

    # Add title
    plt.title(title)

    # Show the chart
    plt.show()

# %%
def plot_audio_features_overtime(df,plot_features,title):
    columns = df.columns.tolist()
    delete_col = []
    for c in columns:
        if not c in plot_features and c != "endTime":
            delete_col.append(c)
    df.drop(columns=delete_col, inplace=True)
    df['endTime'] = df['endTime'].apply(lambda x: x.split(" ")[0])
    df['endTime'] = pd.to_datetime(df['endTime'])
    df = df.set_index('endTime')
    df = df.groupby(pd.Grouper(freq='d')).mean()
    df.fillna(0,inplace=True)
    df = df/df.sum()
    df.plot(kind='line', y=plot_features, figsize=(12, 6), xlabel="Time(d)",ylabel="Score", title=title)

# %% [markdown]
# # Analysis

# %%
# Load JSON file into a Pandas DataFrame
streaming = pd.read_json('../data/StreamingHistory1.json')
search_queries = pd.read_json('../data/SearchQueries.json')
streaming.head()
# Out:
#             endTime          artistName     trackName  msPlayed
# 0  2023-01-05 16:22      Anna Landström   To the Rain    141966
# 1  2023-01-05 16:25  Joy Meyer-Williams  Autumn Night    172896
# 2  2023-01-05 16:28         Jon Hopkins   Wintergreen    180531
# 3  2023-01-05 16:30            Igulfrid      Hideaway    146806
# 4  2023-01-05 16:32    Giovanna Petrini  Nascondiglio    116950

# %%
streaming.describe()
# Out:
#            msPlayed
# count  3.372000e+03
# mean   1.497198e+05
# std    2.434860e+05
# min    0.000000e+00
# 25%    9.306000e+03
# 50%    1.347610e+05
# 75%    1.910260e+05
# max    5.078208e+06

# %%
search_queries.head()
# Out:
#        platform                     searchTime searchQuery  \
# 0  IPHONE_ARM64  2023-01-11T21:04:19.981Z[UTC]         bla
# 1  IPHONE_ARM64  2023-01-11T21:04:24.375Z[UTC]     simply
# 2  IPHONE_ARM64  2023-01-29T19:13:57.108Z[UTC]       malo
# 3  IPHONE_ARM64  2023-02-01T15:34:20.004Z[UTC]          l’
# 4        IPHONE  2023-02-01T15:34:21.141Z[UTC]    l’appunt
#
#                     searchInteractionURIs
# 0                                      []
# 1                                      []
# 2                                      []
# 3                                      []
# 4  [spotify:track:5PnEkOUOFnk0wMI71JwddQ]

# %%
search_queries.describe()
# Out:
#        platform                     searchTime     searchQuery  \
# count        40                             40              40
# unique        3                             40              35
# top      IPHONE  2023-01-11T21:04:19.981Z[UTC]  i will survive
# freq         19                              1               3
#
#        searchInteractionURIs
# count                     40
# unique                    18
# top                       []
# freq                      23

# %%
# display a frequency of words in world-cloud search history
word_cloud(search_queries['searchQuery'])

# %%
# display a frequency of words in world-cloud artist
word_cloud(streaming['artistName'])

# %%
create_bar_chart(search_queries['platform'], "number queries", "platform", "Search queries vs platform")

# %%
new_df = streaming.head(20).groupby('trackName').sum().reset_index()
create_pie_chart(new_df, 'trackName', 'msPlayed','Time spent in last 20 most plated tracks')
# Out:
# C:\Users\Diego\AppData\Local\Temp\ipykernel_14496\3497814960.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new_df = streaming.head(20).groupby('trackName').sum().reset_index()

# %%
new_df = streaming.head(20).groupby('artistName').sum().reset_index()
create_pie_chart(new_df, 'artistName', 'msPlayed', 'Time spent in last 20 songs by most played artists')
# Out:
# /var/folders/dn/x_8ks55n46x692nkj1bx2rbw0000gn/T/ipykernel_447/3143662739.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.

# %% [markdown]
# # SPOTIFY API EXPLORATION

# %%
import requests

streaming.head(30)
# Out:
#              endTime          artistName                        trackName  \
# 0   2023-01-05 16:22      Anna Landström                      To the Rain
# 1   2023-01-05 16:25  Joy Meyer-Williams                     Autumn Night
# 2   2023-01-05 16:28         Jon Hopkins                      Wintergreen
# 3   2023-01-05 16:30            Igulfrid                         Hideaway
# 4   2023-01-05 16:32    Giovanna Petrini                     Nascondiglio
# 5   2023-01-05 16:33                Mree                              May
# 6   2023-01-05 16:36    Piano Melancolía                             Silk
# 7   2023-01-05 16:38      Elder Lockhart              Ex Nihilo Nihil Fit
# 8   2023-01-05 16:40                Nsee                      Frozen Lake
# 9   2023-01-05 16:42           Noah Foem                             Days
# 10  2023-01-05 17:58         Ron Adelaar                       Letting Go
# 11  2023-01-05 21:03            Raffa Fl                            Ritmo
# 12  2023-01-06 07:52               Bicep                         Apricots
# 13  2023-01-06 07:58               Gidge                           Quasar
# 14  2023-01-06 07:58               Gidge                           Quasar
# 15  2023-01-06 07:58        Fred again..       Marea (we’ve lost dancing)
# 16  2023-01-06 07:58        Fred again..       Marea (we’ve lost dancing)
# 17  2023-01-06 07:58            Bee Gees                      Night Fever
# 18  2023-01-06 08:02               Bicep                         Apricots
# 19  2023-01-06 08:07               Gidge                           Quasar
# 20  2023-01-06 08:46    Johannes Bornlöf                       As I Dream
# 21  2023-01-06 08:49          Nel Swerts                        Un Cadeau
# 22  2023-01-06 08:52         Lake Isabel                   Crossing Paths
# 23  2023-01-06 08:54       Tom Kristiaan  Un sourire et une larme (valse)
# 24  2023-01-06 08:57   Dustin O'Halloran         Opus 18 - Silfur Version
# 25  2023-01-06 08:59         Jacob David                         Nowesind
# 26  2023-01-06 09:02     Helmut Schenker                             Alba
# 27  2023-01-06 09:04     Isshi Matsuriza                        Shizukana
# 28  2023-01-06 09:06         Norman Dück                          Reframe
# 29  2023-01-06 09:09        Chris Donner                        Homestead
#
#     msPlayed
# 0     141966
# 1     172896
# 2     180531
# 3     146806
# 4     116950
# 5      76937
# 6     148835
# 7     140151
# 8     117443
# 9     135859
# 10     77309
# 11      1695
# 12      1764
# 13     11192
# 14    352215
# 15     18340
# 16       859
# 17      1718
# 18    246506
# 19    250226
# 20    178613
# 21    153484
# 22    174272
# 23    140356
# 24    200194
# 25    112333
# 26    148830
# 27    128634
# 28    124612
# 29    157962

# %%
def spotify_search_track(track_name: str, access_token: str):
    request = requests.get('https://api.spotify.com/v1/search?q=' + track_name + '&type=track', headers={'Authorization': 'Bearer ' + access_token})
    return request.json()

# %%
def spotify_fetch_album(album_id: str, access_token: str):
    request = requests.get('https://api.spotify.com/v1/albums/' + album_id, headers={'Authorization': 'Bearer ' + access_token})
    return request.json()

# %%
access_token = "PLACE YOUR TOKEN HERE"
it = 0
def get_track_info(track_row):
    track_name = track_row["trackName"]
    req1 = spotify_search_track(track_name, access_token)
    #Check if we have a successful response
    if(req1 and 'tracks' in req1):
        tracks_results = req1['tracks']['items']
        first_result = tracks_results[0]
        id = first_result['id']
        track_info = {
            'id' : first_result['id'],
            'album_id': first_result['album']['id'],
            'album_name': first_result['album']['name'],
            'duration_ms' : first_result['duration_ms'],
            'popularity' : first_result['popularity'],
            'track_name': first_result['name'],
            'artists': list(map(lambda x: x['name'], first_result['artists'])),
            'msPlayed': track_row['msPlayed'],
            'endTime': track_row['endTime']
        }
        #Second API request for more information about the album (release date, genres)
        req2 = spotify_fetch_album(track_info['album_id'], access_token)
        if(req2):
            track_info['release_date'] = req2['release_date']
            track_info['genres'] = req2['genres']
            return pd.Series(track_info)

# %% [markdown]
# # Let's get the data for the Data frame then :)

# %%
# nb = len(streaming)
df = streaming.head(5)
df = df.apply(get_track_info, axis=1)
print("Result df: ", df)
df.to_csv("../out" + str(nb)+"-results.csv")
# Out:
# Result df:  0    None
# 1    None
# 2    None
# 3    None
# 4    None
# dtype: object

# %%
# replace with your own client ID and client secret from the Spotify Developer Dashboard
with open("secrets.txt") as file:
    client_id = file.readline()
    client_secret = file.readline()

# load the CSV file into a pandas DataFrame
results = pd.read_csv('../out/merged-res.csv')
results.head()
# Out:
#    Unnamed: 0                      id                album_id  \
# 0           0  025aQi6Ffw676y8m4zLPk7  30HSC1ogeWpwBZXroMTTDW
# 1           1  5eMUmyDeH1aayf1uZ0Wrga  2EqOuPPTOth7VS70I1kvta
# 2           2  7EL9YtzL4qYOcxYlf4mbVi  2zXp7huP6HGVldywEC6arL
# 3           3  2HwCcCi8Up9NECNBRt0yTV  1Vhx6ow2PDJROoX3ND5dEy
# 4           4  763DOeT2XIrzMjbC3LLF5i  4TVVWsBh3tY8GXupSSoCc4
#
#          album_name  duration_ms  popularity        track_name  \
# 0       To the Rain     145620.0        59.0       To the Rain
# 1   Reflect the Day      65142.0        48.0     Autumn Nights
# 2    Yours to Break     211826.0        52.0       Wintergreen
# 3          Hideaway     148906.0        63.0          Hideaway
# 4  Lydian Fairytale     105786.0        67.0  Lydian Fairytale
#
#                                      artists  msPlayed           endTime  \
# 0                         ['Anna Landström']  141966.0  2023-01-05 16:22
# 1  ['Slowberry', 'Fuzzy & Glad', 'blushful']  172896.0  2023-01-05 16:25
# 2                      ['The East Pointers']  180531.0  2023-01-05 16:28
# 3                               ['Igulfrid']  146806.0  2023-01-05 16:30
# 4                           ['Nascondiglio']  116950.0  2023-01-05 16:32
#
#   release_date genres
# 0   2022-05-20     []
# 1   2020-10-05     []
# 2   2019-10-25     []
# 3   2022-04-15     []
# 4   2022-12-30     []

# %%
import math
data_retrieved = []
for track_id in results['id']:
    # set up authentication for the Spotify API
    client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
    sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
    print(track_id)
    if(track_id == track_id):
        print(track_id)

    # make the request to the Spotify API to get the audio features for the track
        audio_features = sp.audio_features(track_id)
        data_retrieved.append(audio_features[0])

frame_audio_features = pd.DataFrame(data_retrieved)
frame_audio_features.head()
# Out:
# 025aQi6Ffw676y8m4zLPk7
# 025aQi6Ffw676y8m4zLPk7
# 5eMUmyDeH1aayf1uZ0Wrga
# 5eMUmyDeH1aayf1uZ0Wrga
# 7EL9YtzL4qYOcxYlf4mbVi
# 7EL9YtzL4qYOcxYlf4mbVi
# 2HwCcCi8Up9NECNBRt0yTV
# 2HwCcCi8Up9NECNBRt0yTV
# 763DOeT2XIrzMjbC3LLF5i
# 763DOeT2XIrzMjbC3LLF5i
# 2BHj31ufdEqVK5CkYDp9mA
# 2BHj31ufdEqVK5CkYDp9mA
# 2kEk2uIKtoJD5r65cH7XBP
# 2kEk2uIKtoJD5r65cH7XBP
# 3iyH2B4dcjufYE0ZjiUZsC
# 3iyH2B4dcjufYE0ZjiUZsC
# 0acEauszFAvCGw9cNF0kZM
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.927000    0.0829    0.317  111.993  audio_features
# 1          0.973000    0.1020    0.000   70.036  audio_features
# 2          0.000005    0.0745    0.395  184.286  audio_features
# 3          0.929000    0.0996    0.154   84.753  audio_features
# 4          0.912000    0.1170    0.175   70.853  audio_features
#
#                        id                                   uri  \
# 0  025aQi6Ffw676y8m4zLPk7  spotify:track:025aQi6Ffw676y8m4zLPk7
# 1  5eMUmyDeH1aayf1uZ0Wrga  spotify:track:5eMUmyDeH1aayf1uZ0Wrga
# 2  7EL9YtzL4qYOcxYlf4mbVi  spotify:track:7EL9YtzL4qYOcxYlf4mbVi
# 3  2HwCcCi8Up9NECNBRt0yTV  spotify:track:2HwCcCi8Up9NECNBRt0yTV
# 4  763DOeT2XIrzMjbC3LLF5i  spotify:track:763DOeT2XIrzMjbC3LLF5i
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/025aQi6Ffw67...
# 1  https://api.spotify.com/v1/tracks/5eMUmyDeH1aa...
# 2  https://api.spotify.com/v1/tracks/7EL9YtzL4qYO...
# 3  https://api.spotify.com/v1/tracks/2HwCcCi8Up9N...
# 4  https://api.spotify.com/v1/tracks/763DOeT2XIrz...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/025a...       145621
# 1  https://api.spotify.com/v1/audio-analysis/5eMU...        65143
# 2  https://api.spotify.com/v1/audio-analysis/7EL9...       211827
# 3  https://api.spotify.com/v1/audio-analysis/2HwC...       148907
# 4  https://api.spotify.com/v1/audio-analysis/763D...       105787
#
#    time_signature
# 0               4
# 1               4
# 2               3
# 3               4
# 4               4

# %%
#merge both datasets
merged_extra_info = pd.merge(results, frame_audio_features, on='id')
merged_extra_info.head()
# Out:
#    Unnamed: 0                      id                album_id   album_name  \
# 0           0  025aQi6Ffw676y8m4zLPk7  30HSC1ogeWpwBZXroMTTDW  To the Rain
# 1           0  025aQi6Ffw676y8m4zLPk7  30HSC1ogeWpwBZXroMTTDW  To the Rain
# 2           0  025aQi6Ffw676y8m4zLPk7  30HSC1ogeWpwBZXroMTTDW  To the Rain
# 3           0  025aQi6Ffw676y8m4zLPk7  30HSC1ogeWpwBZXroMTTDW  To the Rain
# 4           0  025aQi6Ffw676y8m4zLPk7  30HSC1ogeWpwBZXroMTTDW  To the Rain
#
#    duration_ms_x  popularity   track_name             artists  msPlayed  \
# 0       145620.0        59.0  To the Rain  ['Anna Landström']  141966.0
# 1       145620.0        59.0  To the Rain  ['Anna Landström']  141966.0
# 2       145620.0        59.0  To the Rain  ['Anna Landström']  141966.0
# 3       145620.0        59.0  To the Rain  ['Anna Landström']  141966.0
# 4       145620.0        59.0  To the Rain  ['Anna Landström']  141966.0
#
#             endTime  ... instrumentalness liveness  valence    tempo  \
# 0  2023-01-05 16:22  ...            0.927   0.0829    0.317  111.993
# 1  2023-01-05 16:22  ...            0.927   0.0829    0.317  111.993
# 2  2023-01-05 16:22  ...            0.927   0.0829    0.317  111.993
# 3  2023-01-05 16:22  ...            0.927   0.0829    0.317  111.993
# 4  2023-01-05 16:22  ...            0.927   0.0829    0.317  111.993
#
#              type                                   uri  \
# 0  audio_features  spotify:track:025aQi6Ffw676y8m4zLPk7
# 1  audio_features  spotify:track:025aQi6Ffw676y8m4zLPk7
# 2  audio_features  spotify:track:025aQi6Ffw676y8m4zLPk7
# 3  audio_features  spotify:track:025aQi6Ffw676y8m4zLPk7
# 4  audio_features  spotify:track:025aQi6Ffw676y8m4zLPk7
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/025aQi6Ffw67...
# 1  https://api.spotify.com/v1/tracks/025aQi6Ffw67...
# 2  https://api.spotify.com/v1/tracks/025aQi6Ffw67...
# 3  https://api.spotify.com/v1/tracks/025aQi6Ffw67...
# 4  https://api.spotify.com/v1/tracks/025aQi6Ffw67...
#
#                                         analysis_url  duration_ms_y  \
# 0  https://api.spotify.com/v1/audio-analysis/025a...         145621
# 1  https://api.spotify.com/v1/audio-analysis/025a...         145621
# 2  https://api.spotify.com/v1/audio-analysis/025a...         145621
# 3  https://api.spotify.com/v1/audio-analysis/025a...         145621
# 4  https://api.spotify.com/v1/audio-analysis/025a...         145621
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
#
# [5 rows x 29 columns]

# %%
merged_extra_info.to_csv("../out/extra_info.csv")

# %%
#load data extra info and clean data
results = pd.read_csv('../out/extra_info.csv')
results.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                      id                album_id  \
# 0             0           0  025aQi6Ffw676y8m4zLPk7  30HSC1ogeWpwBZXroMTTDW
# 1             1           0  025aQi6Ffw676y8m4zLPk7  30HSC1ogeWpwBZXroMTTDW
# 2             2           0  025aQi6Ffw676y8m4zLPk7  30HSC1ogeWpwBZXroMTTDW
# 3             3           0  025aQi6Ffw676y8m4zLPk7  30HSC1ogeWpwBZXroMTTDW
# 4             4           0  025aQi6Ffw676y8m4zLPk7  30HSC1ogeWpwBZXroMTTDW
#
#     album_name  duration_ms_x  popularity   track_name             artists  \
# 0  To the Rain       145620.0        59.0  To the Rain  ['Anna Landström']
# 1  To the Rain       145620.0        59.0  To the Rain  ['Anna Landström']
# 2  To the Rain       145620.0        59.0  To the Rain  ['Anna Landström']
# 3  To the Rain       145620.0        59.0  To the Rain  ['Anna Landström']
# 4  To the Rain       145620.0        59.0  To the Rain  ['Anna Landström']
#
#    msPlayed  ... instrumentalness liveness valence    tempo            type  \
# 0  141966.0  ...            0.927   0.0829   0.317  111.993  audio_features
# 1  141966.0  ...            0.927   0.0829   0.317  111.993  audio_features
# 2  141966.0  ...            0.927   0.0829   0.317  111.993  audio_features
# 3  141966.0  ...            0.927   0.0829   0.317  111.993  audio_features
# 4  141966.0  ...            0.927   0.0829   0.317  111.993  audio_features
#
#                                     uri  \
# 0  spotify:track:025aQi6Ffw676y8m4zLPk7
# 1  spotify:track:025aQi6Ffw676y8m4zLPk7
# 2  spotify:track:025aQi6Ffw676y8m4zLPk7
# 3  spotify:track:025aQi6Ffw676y8m4zLPk7
# 4  spotify:track:025aQi6Ffw676y8m4zLPk7
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/025aQi6Ffw67...
# 1  https://api.spotify.com/v1/tracks/025aQi6Ffw67...
# 2  https://api.spotify.com/v1/tracks/025aQi6Ffw67...
# 3  https://api.spotify.com/v1/tracks/025aQi6Ffw67...
# 4  https://api.spotify.com/v1/tracks/025aQi6Ffw67...
#
#                                         analysis_url  duration_ms_y  \
# 0  https://api.spotify.com/v1/audio-analysis/025a...         145621
# 1  https://api.spotify.com/v1/audio-analysis/025a...         145621
# 2  https://api.spotify.com/v1/audio-analysis/025a...         145621
# 3  https://api.spotify.com/v1/audio-analysis/025a...         145621
# 4  https://api.spotify.com/v1/audio-analysis/025a...         145621
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
#
# [5 rows x 30 columns]

# %%
drop_columns = ["Unnamed: 0.1","Unnamed: 0","uri", "track_href", "analysis_url", "duration_ms_y", "type","duration_ms_x"]
extra_results = results.drop(drop_columns , axis=1)

extra_results['endTime'] = pd.to_datetime(extra_results['endTime'])
extra_results['endTime'] = extra_results['endTime'].dt.strftime('%Y-%m-%d')

extra_results.describe()
# Out:
#         popularity       msPlayed  danceability       energy          key  \
# count  3677.000000    3677.000000   3677.000000  3677.000000  3677.000000
# mean     55.965461  165355.734294      0.486375     0.262508     5.570302
# std      14.031701  101584.524899      0.192118     0.300805     3.552156
# min       0.000000      70.000000      0.130000     0.000860     0.000000
# 25%      50.000000  119248.000000      0.319000     0.025000     2.000000
# 50%      59.000000  146372.000000      0.441000     0.063100     5.000000
# 75%      63.000000  195503.000000      0.642000     0.491000     8.000000
# max      94.000000  469995.000000      0.964000     0.974000    11.000000
#
#           loudness         mode  speechiness  acousticness  instrumentalness  \
# count  3677.000000  3677.000000  3677.000000   3677.000000       3677.000000
# mean    -20.853534     0.572478     0.063788      0.679304          0.721258
# std       9.971354     0.494786     0.068281      0.393911          0.357953
# min     -38.342000     0.000000     0.024800      0.000033          0.000000
# 25%     -28.755000     0.000000     0.037100      0.288000          0.801000
# 50%     -26.028000     1.000000     0.045600      0.973000          0.913000
# 75%     -11.674000     1.000000     0.057700      0.993000          0.941000
# max      -2.410000     1.000000     0.421000      0.996000          0.974000
#
#           liveness      valence        tempo  time_signature
# count  3677.000000  3677.000000  3677.000000     3677.000000
# mean      0.123794     0.235052   112.165120        3.711450
# std       0.077171     0.198654    27.107941        0.649526
# min       0.026500     0.000000    52.158000        1.000000
# 25%       0.094700     0.092200    89.040000        3.000000
# 50%       0.109000     0.159000   117.002000        4.000000
# 75%       0.115000     0.318000   128.537000        4.000000
# max       0.712000     0.973000   206.686000        5.000000

# %%
grouped = extra_results.groupby('endTime').sum()
grouped_normalised = grouped
grouped_normalised.head()
# Out:
# C:\Users\Diego\AppData\Local\Temp\ipykernel_14496\2218286013.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped = extra_results.groupby('endTime').sum()
#             popularity     msPlayed  danceability     energy   key   loudness  \
# endTime
# 2023-01-05      3307.0    7183332.0        26.363   12.21370   400  -1248.683
# 2023-01-06     57181.0  171115863.0       482.619  257.14480  5652 -21071.223
# 2023-01-07     40579.0  117178218.0       328.156  192.28224  4106 -15054.808
# 2023-01-08        92.0      32244.0         0.445    0.53700     4     -8.532
# 2023-01-09     31607.0   94508192.0       262.732  105.08590  3266 -13778.848
#
#             mode  speechiness  acousticness  instrumentalness  liveness  \
# endTime
# 2023-01-05    36       3.6806     42.607000         38.638361    6.4580
# 2023-01-06   578      60.5078    701.590027        741.771473  133.9045
# 2023-01-07   329      44.0061    522.786770        512.671387   86.0682
# 2023-01-08     0       0.0400      0.695000          0.000017    0.0944
# 2023-01-09   329      41.7195    472.191260        451.326147   67.4840
#
#              valence       tempo  time_signature
# endTime
# 2023-01-05   13.5436    5955.903             212
# 2023-01-06  233.8032  112513.436            3769
# 2023-01-07  172.8980   81805.099            2682
# 2023-01-08    0.1310     122.769               4
# 2023-01-09  121.7502   64239.005            2164

# %%
grouped_normalised.plot(kind='bar',y=["valence"],ylabel="happines value", title="Your sentiment in the last days")
# Out:
# <AxesSubplot: title={'center': 'Your sentiment in the last days'}, xlabel='endTime', ylabel='happines value'>

# %%
trackPopularity = results.groupby('track_name').mean()
grouped_normalised.plot(kind='scatter', x='msPlayed', y='popularity', title="correlation between time spend in songs and popularity")
# Out:
# C:\Users\Diego\AppData\Local\Temp\ipykernel_14496\2490117880.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# <AxesSubplot: title={'center': 'correlation between time spend in songs and popularity'}, xlabel='msPlayed', ylabel='popularity'>

# %%
df = results.copy()
print(df['endTime'])
df['endTime'] = df['endTime'].apply(lambda x: x.split(" ")[0])
df['endTime'] = pd.to_datetime(df['endTime'])
print(df['endTime'])
df = df.set_index('endTime')
df = df.groupby(pd.Grouper(freq='d')).mean()
df['endTime'] = df.index
df['endTime_str'] = df['endTime'].apply(lambda x: calendar.day_name[x.weekday()])
df = df.groupby(['endTime_str']).mean()

print(df)

df['endTime_str'] = df.index


fig = px.line_polar(df, r='valence', theta='endTime_str', line_close=True, labels=["valence, endTime"])
fig.update_layout(showlegend=True, template="plotly_dark", title="Mean valence by weekday")
# fig.show()
# Out:
# 0       2023-01-05 16:22
# 1       2023-01-05 16:22
# 2       2023-01-05 16:22
# 3       2023-01-05 16:22
# 4       2023-01-05 16:22
#               ...
# 3672    2023-01-14 10:17
# 3673    2023-01-14 10:20
# 3674    2023-01-14 10:20
# 3675    2023-01-14 16:04
# 3676    2023-01-14 16:18
# Name: endTime, Length: 3677, dtype: object
# 0      2023-01-05
# 1      2023-01-05
# 2      2023-01-05
# 3      2023-01-05
# 4      2023-01-05
#           ...
# 3672   2023-01-14
# 3673   2023-01-14
# 3674   2023-01-14
# 3675   2023-01-14
# 3676   2023-01-14
# Name: endTime, Length: 3677, dtype: datetime64[ns]
#              Unnamed: 0.1  Unnamed: 0  duration_ms_x  popularity  \
# endTime_str
# Friday        2396.027485  292.288153  264334.947564   57.472642
# Monday        1721.916382  315.496587  190938.465870   53.936860
# Saturday      1557.058330  408.353302  187797.792988   56.526911
# Sunday        3327.000000  272.000000  244360.000000   92.000000
# Thursday       145.649123    5.333333  166816.684211   58.017544
# Tuesday       2321.536998  414.479915  219863.350951   53.644820
# Wednesday     1101.852941  465.382353  247608.735294   60.058824
#
#                   msPlayed  danceability    energy       key   loudness  \
# endTime_str
# Friday       199208.060673      0.601144  0.410277  5.883748 -16.056913
# Monday       161276.778157      0.448348  0.179327  5.573379 -23.513392
# Saturday     152439.169799      0.423988  0.181004  5.469041 -23.806112
# Sunday        32244.000000      0.445000  0.537000  4.000000  -8.532000
# Thursday     126023.368421      0.462509  0.214275  7.017544 -21.906719
# Tuesday      142079.942918      0.514638  0.292776  4.961945 -19.736668
# Wednesday    246275.676471      0.596471  0.709118  6.735294  -6.188029
#
#                  mode  speechiness  acousticness  instrumentalness  liveness  \
# endTime_str
# Friday       0.648687     0.063501      0.429147          0.625861  0.130651
# Monday       0.561433     0.071194      0.805787          0.770181  0.115160
# Saturday     0.519690     0.057059      0.807672          0.776406  0.113628
# Sunday       0.000000     0.040000      0.695000          0.000017  0.094400
# Thursday     0.631579     0.064572      0.747491          0.677866  0.113298
# Tuesday      0.672304     0.073648      0.605092          0.706371  0.133363
# Wednesday    0.117647     0.084056      0.334668          0.450921  0.157826
#
#               valence       tempo  duration_ms_y  time_signature
# endTime_str
# Friday       0.276863  113.428522  264335.355181        3.859571
# Monday       0.207765  109.622875  190938.860068        3.692833
# Saturday     0.214012  114.229367  187798.155829        3.576504
# Sunday       0.131000  122.769000  244360.000000        4.000000
# Thursday     0.237607  104.489526  166817.333333        3.719298
# Tuesday      0.248854  111.751892  219863.731501        3.733615
# Wednesday    0.280353  102.303412  247608.823529        4.000000
# C:\Users\Diego\AppData\Local\Temp\ipykernel_14496\281446335.py:7: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# C:\Users\Diego\AppData\Local\Temp\ipykernel_14496\281446335.py:10: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# D:\python3.10\lib\site-packages\plotly\express\_core.py:271: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="1865465c-ee22-4fa8-8069-def146f02024" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1865465c-ee22-4fa8-8069-def146f02024")) {                    Plotly.newPlot(                        "1865465c-ee22-4fa8-8069-def146f02024",                        [{"hovertemplate":"valence=%{r}<br>endTime_str=%{theta}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","r":[0.276862711938587,0.20776484641638227,0.2140116685174564,0.131,0.23760701754385966,0.24885412262156448,0.2803529411764706,0.276862711938587],"showlegend":false,"subplot":"polar","theta":["Friday","Monday","Saturday","Sunday","Thursday","Tuesday","Wednesday","Friday"],"type":"scatterpolar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"autom ...

# %%
df = results.copy()
print(df['endTime'])
df['endTime'] = df['endTime'].apply(lambda x: x.split(" ")[0])
df['endTime'] = pd.to_datetime(df['endTime'])
print(df['endTime'])
df = df.set_index('endTime')
df = df.groupby(pd.Grouper(freq='d')).mean()
df['endTime'] = df.index
df['endTime_str'] = df['endTime'].apply(lambda x: calendar.day_name[x.weekday()])
df = df.groupby(['endTime_str']).mean()

print(df)

df['endTime_str'] = df.index


fig = px.line_polar(df, r='energy', theta='endTime_str', line_close=True, labels=["energy, endTime"], template="plotly_dark",)
fig.update_layout(showlegend=True, title="Mean track energy by weekday")
fig.show()
# Out:
# 0       2023-01-05 16:22
# 1       2023-01-05 16:22
# 2       2023-01-05 16:22
# 3       2023-01-05 16:22
# 4       2023-01-05 16:22
#               ...
# 3672    2023-01-14 10:17
# 3673    2023-01-14 10:20
# 3674    2023-01-14 10:20
# 3675    2023-01-14 16:04
# 3676    2023-01-14 16:18
# Name: endTime, Length: 3677, dtype: object
# 0      2023-01-05
# 1      2023-01-05
# 2      2023-01-05
# 3      2023-01-05
# 4      2023-01-05
#           ...
# 3672   2023-01-14
# 3673   2023-01-14
# 3674   2023-01-14
# 3675   2023-01-14
# 3676   2023-01-14
# Name: endTime, Length: 3677, dtype: datetime64[ns]
#              Unnamed: 0.1  Unnamed: 0  duration_ms_x  popularity  \
# endTime_str
# Friday        2396.027485  292.288153  264334.947564   57.472642
# Monday        1721.916382  315.496587  190938.465870   53.936860
# Saturday      1557.058330  408.353302  187797.792988   56.526911
# Sunday        3327.000000  272.000000  244360.000000   92.000000
# Thursday       145.649123    5.333333  166816.684211   58.017544
# Tuesday       2321.536998  414.479915  219863.350951   53.644820
# Wednesday     1101.852941  465.382353  247608.735294   60.058824
#
#                   msPlayed  danceability    energy       key   loudness  \
# endTime_str
# Friday       199208.060673      0.601144  0.410277  5.883748 -16.056913
# Monday       161276.778157      0.448348  0.179327  5.573379 -23.513392
# Saturday     152439.169799      0.423988  0.181004  5.469041 -23.806112
# Sunday        32244.000000      0.445000  0.537000  4.000000  -8.532000
# Thursday     126023.368421      0.462509  0.214275  7.017544 -21.906719
# Tuesday      142079.942918      0.514638  0.292776  4.961945 -19.736668
# Wednesday    246275.676471      0.596471  0.709118  6.735294  -6.188029
#
#                  mode  speechiness  acousticness  instrumentalness  liveness  \
# endTime_str
# Friday       0.648687     0.063501      0.429147          0.625861  0.130651
# Monday       0.561433     0.071194      0.805787          0.770181  0.115160
# Saturday     0.519690     0.057059      0.807672          0.776406  0.113628
# Sunday       0.000000     0.040000      0.695000          0.000017  0.094400
# Thursday     0.631579     0.064572      0.747491          0.677866  0.113298
# Tuesday      0.672304     0.073648      0.605092          0.706371  0.133363
# Wednesday    0.117647     0.084056      0.334668          0.450921  0.157826
#
#               valence       tempo  duration_ms_y  time_signature
# endTime_str
# Friday       0.276863  113.428522  264335.355181        3.859571
# Monday       0.207765  109.622875  190938.860068        3.692833
# Saturday     0.214012  114.229367  187798.155829        3.576504
# Sunday       0.131000  122.769000  244360.000000        4.000000
# Thursday     0.237607  104.489526  166817.333333        3.719298
# Tuesday      0.248854  111.751892  219863.731501        3.733615
# Wednesday    0.280353  102.303412  247608.823529        4.000000
# C:\Users\Diego\AppData\Local\Temp\ipykernel_14496\3371085935.py:7: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# C:\Users\Diego\AppData\Local\Temp\ipykernel_14496\3371085935.py:10: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# D:\python3.10\lib\site-packages\plotly\express\_core.py:271: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="ed2df877-212f-4c7a-9efd-a8f0be7b8e28" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed2df877-212f-4c7a-9efd-a8f0be7b8e28")) {                    Plotly.newPlot(                        "ed2df877-212f-4c7a-9efd-a8f0be7b8e28",                        [{"hovertemplate":"energy=%{r}<br>endTime_str=%{theta}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","r":[0.4102767364302408,0.17932747440273036,0.1810041816661989,0.537,0.21427543859649123,0.2927759408033827,0.7091176470588235,0.4102767364302408],"showlegend":false,"subplot":"polar","theta":["Friday","Monday","Saturday","Sunday","Thursday","Tuesday","Wednesday","Friday"],"type":"scatterpolar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"autom ...

# %%
df = results.copy()
print(df['endTime'])
df['endTime'] = df['endTime'].apply(lambda x: x.split(" ")[0])
df['endTime'] = pd.to_datetime(df['endTime'])
df = df.set_index('endTime')
df = df.groupby(pd.Grouper(freq='d')).mean()
df = df.interpolate()
fig = px.line(df, x=df.index, y="danceability", title='Danceability through time')
fig.show()
# Out:
# 0       2023-01-05 16:22
# 1       2023-01-05 16:22
# 2       2023-01-05 16:22
# 3       2023-01-05 16:22
# 4       2023-01-05 16:22
#               ...
# 3672    2023-01-14 10:17
# 3673    2023-01-14 10:20
# 3674    2023-01-14 10:20
# 3675    2023-01-14 16:04
# 3676    2023-01-14 16:18
# Name: endTime, Length: 3677, dtype: object
# C:\Users\Diego\AppData\Local\Temp\ipykernel_14496\1857979226.py:6: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# <div>                            <div id="acab6d11-fea6-42b6-a9ae-d7ccd3377eb8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("acab6d11-fea6-42b6-a9ae-d7ccd3377eb8")) {                    Plotly.newPlot(                        "acab6d11-fea6-42b6-a9ae-d7ccd3377eb8",                        [{"hovertemplate":"endTime=%{x}<br>danceability=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2023-01-05T00:00:00","2023-01-06T00:00:00","2023-01-07T00:00:00","2023-01-08T00:00:00","2023-01-09T00:00:00","2023-01-10T00:00:00","2023-01-11T00:00:00","2023-01-12T00:00:00","2023-01-13T00:00:00","2023-01-14T00:00:00"],"xaxis":"x","y":[0.46250877192982454,0.4773679525222552,0.4545096952908587,0.445,0.44834812286689424,0.5146384778012685,0.5964705882352942,0.6606954711087976,0.7249203539823008,0.3934669603524229],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{" ...

# %%
image = Image.open("../images/plot3.png")
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1388x450>

# %%
plot_audio_features_overtime(results.copy(),["danceability",	"energy",	"key",	"loudness",	"mode",	"speechiness",	"acousticness",	"instrumentalness",	"liveness",	"valence"	], "Audio features against days")
